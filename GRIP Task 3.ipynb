# %% [markdown]
# # GRIP Task3

# %% [markdown]
# # Raghav Sharma

# %% [markdown]
# # Exploratory Data Analytics-Retail

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv(r'C:\Users\RAGHAV\Documents\Tableau files\SampleSuperstore.csv')
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
sns.heatmap(df.corr(),annot=True)
plt.figure(figsize=(10,15))

# %% [markdown]
# # Exploratory Data Analytics

# %%
plt.figure(figsize=(10,10))
sns.set_style('darkgrid')
sns.barplot(x=df['Region'],y=df['Profit'],hue=df['Segment'])
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Profit'>

# %% [markdown]
# # Insights

# %% [markdown]
# 1. South has highest profit in Consumer segment
# 2. West has highest profit in Corporate segment
# 3. Central has highest profit in Home Office segment
# 4. East has highest profit in Home Office segment

# %%
sub=df.groupby('Ship Mode')['Sales','Profit'].mean()
sub
# Out:
# C:\Users\RAGHAV\AppData\Local\Temp/ipykernel_2116/3669854005.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   sub=df.groupby('Ship Mode')['Sales','Profit'].mean()
#                      Sales     Profit
# Ship Mode
# First Class     228.497024  31.839948
# Same Day        236.396179  29.266591
# Second Class    236.089239  29.535545
# Standard Class  227.583067  27.494770

# %%
sub.plot(x='Ship Mode',y='Sales',
         kind='pie',radius=1.5,
         autopct="%f%%",
         labels=['First Class','Same Day','Second Class','Standard Class'])
plt.legend(loc='center right')
plt.title('Sales Contribution')
# Out:
# Text(0.5, 1.0, 'Sales Contribution')

# %%
sub.plot(x='Ship Mode',y='Profit',
         kind='pie',radius=1.5,
         autopct="%f%%",
         labels=['First Class','Same Day','Second Class','Standard Class'])
plt.legend(loc='center right')
plt.title('Profit Contribution')
# Out:
# Text(0.5, 1.0, 'Profit Contribution')

# %% [markdown]
# # Finding insights and patters from the dataset

# %%
profit=df.groupby('State')['Profit'].sum()
profit
# Out:
# State
# Alabama                  5786.8253
# Arizona                 -3427.9246
# Arkansas                 4008.6871
# California              76381.3871
# Colorado                -6527.8579
# Connecticut              3511.4918
# Delaware                 9977.3748
# District of Columbia     1059.5893
# Florida                 -3399.3017
# Georgia                 16250.0433
# Idaho                     826.7231
# Illinois               -12607.8870
# Indiana                 18382.9363
# Iowa                     1183.8119
# Kansas                    836.4435
# Kentucky                11199.6966
# Louisiana                2196.1023
# Maine                     454.4862
# Maryland                 7031.1788
# Massachusetts            6785.5016
# Michigan                24463.1876
# Minnesota               10823.1874
# Mississippi              3172.9762
# Missouri                 6436.2105
# Montana                  1833.3285
# Nebraska                 2037.0942
# ...

# %%
print(f'The State with highest profit is {profit.idxmax()} and the profit numbers are {profit.max()}' )
print(f'The State with highest loss is {profit.idxmin()} and the loss numbers are {profit.min()}' )
# Out:
# The State with highest profit is California and the profit numbers are 76381.38709999999
# The State with highest loss is Texas and the loss numbers are -25729.3563

# %%
plt.figure(figsize=(15,20))
sns.set_style('darkgrid')
profit.plot(kind='barh')
plt.xlabel('Profit')
plt.ylabel('State')
# Out:
# Text(0, 0.5, 'State')

# %% [markdown]
# # Insights

# %% [markdown]
# Oregan and Florida are suffering loss but still less in comparison to Texas

# %%
sales=df.groupby('State')['Sales'].sum()
sales
# Out:
# State
# Alabama                  19510.6400
# Arizona                  35282.0010
# Arkansas                 11678.1300
# California              457687.6315
# Colorado                 32108.1180
# Connecticut              13384.3570
# Delaware                 27451.0690
# District of Columbia      2865.0200
# Florida                  89473.7080
# Georgia                  49095.8400
# Idaho                     4382.4860
# Illinois                 80166.1010
# Indiana                  53555.3600
# Iowa                      4579.7600
# Kansas                    2914.3100
# Kentucky                 36591.7500
# Louisiana                 9217.0300
# Maine                     1270.5300
# Maryland                 23705.5230
# Massachusetts            28634.4340
# Michigan                 76269.6140
# Minnesota                29863.1500
# Mississippi              10771.3400
# Missouri                 22205.1500
# Montana                   5589.3520
# Nebraska                  7464.9300
# ...

# %%
print(f'The State with the highest number of sales is {sales.idxmax()} and the numbers are {sales.max()}')
print(f'The State with the least number of sales is {sales.idxmin()} and the numbers are {sales.min()}')
# Out:
# The State with the highest number of sales is California and the numbers are 457687.6315
# The State with the least number of sales is North Dakota and the numbers are 919.91

# %%
sales_versus_profit=df.groupby('State')['Sales','Profit'].sum()
sales_versus_profit.plot.bar(figsize=(15,20))
plt.show()
# Out:
# C:\Users\RAGHAV\AppData\Local\Temp/ipykernel_2116/3674226574.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   sales_versus_profit=df.groupby('State')['Sales','Profit'].sum()

# %%
discount=df.groupby('State')['Discount'].sum()
discount
# Out:
# State
# Alabama                   0.00
# Arizona                  68.00
# Arkansas                  0.00
# California              145.60
# Colorado                 57.60
# Connecticut               0.60
# Delaware                  0.60
# District of Columbia      0.00
# Florida                 114.65
# Georgia                   0.00
# Idaho                     1.80
# Illinois                191.90
# Indiana                   0.00
# Iowa                      0.00
# Kansas                    0.00
# Kentucky                  0.00
# Louisiana                 0.00
# Maine                     0.00
# Maryland                  0.60
# Massachusetts             2.10
# Michigan                  1.80
# Minnesota                 0.00
# Mississippi               0.00
# Missouri                  0.00
# Montana                   1.00
# Nebraska                  0.00
# Nevada                    2.40
# New Hampshire             0.30
# New Jersey                0.60
# New Mexico                2.20
# ...

# %%
plt.figure(figsize=(15,20))
sns.set_style('darkgrid')
discount.plot(kind='bar')
plt.xlabel('State')
plt.ylabel('Discount')
# Out:
# Text(0, 0.5, 'Discount')

# %% [markdown]
# # Conclusion

# %% [markdown]
# 1. States like Oregan and Florida need to boost up their sales and offer more discounts on their products to increase their overall profit.
# 2. The products should be promoted in states like Kansas, Maine, Montana etc.
# 3. Products have miserably failed in states like Texas,Ohio, Pennsylvania and Illinois.
